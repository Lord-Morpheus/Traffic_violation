# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
pip install ultralytics

# %%
config_file_template = '''
train: /content/drive/MyDrive/Data2/training_data_817Images/M_R_H_NH
val: /content/drive/MyDrive/Data2/validation_data_234Images/M_R_H_NH
test: /content/drive/MyDrive/Data2/testing_data_310Images/M_H_NH(IDD_test_set)

nc: 4
names: [motorcycle,rider,Helmet,
No-Helmet]
'''

with open('/content/drive/MyDrive/data.yaml', 'w') as f:
    f.write(config_file_template)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml').load('yolov8n.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
train_result=model.train(data='/content/drive/MyDrive/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006428 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1EuVYxaVM5l7VPCyTd6HVswNIulpvaI5I/Data2/validation_data_234Images/M_R_H_NH.cache... 1 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1/1 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  8.63it/s]
#                    all          1          2       0.98        0.5      0.995      0.895
#                  rider          1          1       0.96          1      0.995      0.995
#                 Helmet          1          1          1          0      0.995      0.796
# Speed: 0.3ms preprocess, 62.0ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
# !yolo val model='/content/runs/detect/train/weights/best.pt' data='/content/drive/MyDrive/data.yaml' split=test
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006428 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1EuVYxaVM5l7VPCyTd6HVswNIulpvaI5I/Data2/testing_data_310Images/M_H_NH(IDD_test_set)... 102 images, 1 backgrounds, 0 corrupt: 100% 102/102 [00:05<00:00, 17.57it/s]
# val: New cache created: /content/drive/.shortcut-targets-by-id/1EuVYxaVM5l7VPCyTd6HVswNIulpvaI5I/Data2/testing_data_310Images/M_H_NH(IDD_test_set).cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:08<00:00,  1.19s/it]
#                    all        102       1356      0.663      0.033     0.0408     0.0154
#             motorcycle        102        385          1          0     0.0187    0.00675
#                  rider        102        485      0.326      0.126      0.126     0.0465
# ...

# %%
infer.predict("/content/drive/MyDrive/task1test",save=True,save_txt=True,save_conf=True)

# %%
import shutil
source_folder_path = '/content/runs'
destination_folder_path = '/content/drive/MyDrive/dumm'
shutil.move(source_folder_path, destination_folder_path)
# Out:
# '/content/drive/MyDrive/dumm/runs'
