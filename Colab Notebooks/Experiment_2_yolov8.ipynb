# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
pip install ultralytics

# %%
config_file_template = '''
train: /content/drive/MyDrive/Data2/training_data_817Images/M_R_H_NH
val: /content/drive/MyDrive/Data2/validation_data_234Images/M_R_H_NH
test: /content/drive/MyDrive/Data2/testing_data_310Images/M_H_NH(IDD_test_set)

nc: 4
names: [motorcycle,rider,
helmet, no_helmet]
'''

with open('/content/drive/MyDrive/data.yaml', 'w') as f:
    f.write(config_file_template)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml').load('yolov8n.pt')

# %%
train_result=model.train(data='/content/drive/MyDrive/data.yaml', epochs=500, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo val model='/content/drive/MyDrive/best.pt' data='/content/drive/MyDrive/data.yaml' split=test
# Out:
# /bin/bash: yolo: command not found

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25840918 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/cropData/validation_data_234Images/M_R_H_NH.cache... 234 images, 1 backgrounds, 0 corrupt: 100%|██████████| 234/234 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:12<00:00,  1.23it/s]
#                    all        234        539      0.793      0.532      0.619      0.403
#                 Helmet        234        404      0.908      0.678      0.785      0.502
#              No-Helmet        234        135      0.678      0.385      0.453      0.304
# Speed: 1.1ms preprocess, 13.1ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# ...

# %%
# !yolo val model='/content/runs/detect/train/weights/best.pt' data='/content/drive/MyDrive/data.yaml' split=test
# Out:
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25840918 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/cropData/testing_data_310Images/M_H_NH.cache... 114 images, 0 backgrounds, 0 corrupt: 100% 114/114 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:06<00:00,  1.16it/s]
#                    all        114        255      0.714      0.572      0.626      0.374
#                 Helmet        114        166      0.773      0.718      0.761      0.482
#              No-Helmet        114         89      0.654      0.427      0.492      0.266
# Speed: 1.9ms preprocess, 16.7ms inference, 0.0ms loss, 6.3ms postprocess per image
# Results saved to runs/detect/val3
